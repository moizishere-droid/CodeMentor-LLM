# %% [markdown]
# # Phase 21 — Testing (pytest)
# ## CodeMentor-LLM
# Writing unit tests for all critical functions
# using pytest.
#
# ## Test Files
# - test_data_formatter.py — data formatting functions
# - test_data_cleaner.py   — data cleaning functions
# - test_inference.py      — inference pipeline
# - test_api.py            — API endpoints
#
# ## Running Tests
# ```bash
# cd backend
# pytest tests/ -v
# ```
